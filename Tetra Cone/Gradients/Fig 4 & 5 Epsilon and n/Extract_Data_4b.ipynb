# %%
import pandas as pd
import glob

outputs = []

# File-matching pattern
files = sorted(glob.glob("Grad.4b(*).out"))

created_files = []

for fpath in files:
    rows = []
    
    with open(fpath) as f:
        for line in f:
            parts = line.split()

            # Expecting 2 numeric values: ETA, Cf
            if len(parts) >= 2:
                try:
                    eta = float(parts[0])
                    cf  = float(parts[1])
                    
                    rows.append([eta, cf])
                except ValueError:
                    # skip non-numeric lines
                    pass

    # Create DataFrame with NEW headers
    df = pd.DataFrame(rows, columns=['ETA', 'Cf'])

    # Save CSV
    csv_path = fpath.replace('.out', '.csv')
    df.to_csv(csv_path, index=False)

    created_files.append(csv_path)

created_files
# Out:
# ['Grad.4b(1).csv', 'Grad.4b(2).csv', 'Grad.4b(3).csv', 'Grad.4b(4).csv']
