# %% [markdown]
# ## Coding Exercise #0613

# %%
import numpy as np
import warnings
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition  import LatentDirichletAllocation
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#       2 import warnings
#       3 from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# #### 1. Latent Dirichlet Allocation (LDA):

# %%
# The data.
my_docs = ["The economic slowdown is becoming more severe",
           "The movie was simply awesome",
           "I like cooking my own food",
           "Samsung is announcing a new technology",
           "Machine Learning is an example of awesome technology",
           "All of us were excited at the movie",
           "We have to do more to reverse the economic slowdown"]

# %%
my_docs = [x.lower() for x in my_docs]

# %% [markdown]
# #### 1.1. Create a DTM representation:
# CountVectorizer() arguments: <br>
# - *max_features* : maximum number of features (distict words). <br>
# - *min_df* : The minimum DF. Integer value means count and real number (0~1) means proportion. <br>
# - *max_df* : The maximum DF. Integer value means count and real number (0~1) means proportion. Helps to filter out the stop words. <br>

# %%
vectorizer = CountVectorizer(max_features = 15, min_df = 1, max_df = 3, stop_words = ENGLISH_STOP_WORDS)
X = vectorizer.fit_transform(my_docs).toarray()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[4], line 2
#       1 vectorizer = CountVectorizer(max_features = 15, min_df = 1, max_df = 3, stop_words = ENGLISH_STOP_WORDS)
# ----> 2 X = vectorizer.fit_transform(my_docs).toarray()
#
# File c:\Users\admin1\Desktop\New folder\myvenv\Lib\site-packages\sklearn\base.py:1329, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1324 partial_fit_and_fitted = (
#    1325     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1326 )
#    1328 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
#    1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\admin1\Desktop\New folder\myvenv\Lib\site-packages\sklearn\base.py:492, in BaseEstimator._validate_params(self)
#     484 def _validate_params(self):
#     485     """Validate types and values of constructor parameters
#     486
#     487     The expected type and values must be defined in the `_parameter_constraints`
#    (...)    490     accepted constraints.
#     491     """
# --> 492     validate_parameter_constraints(
#     493         self._parameter_constraints,
#     494         self.get_params(deep=False),
#     495         caller_name=self.__class__.__name__,
#     496     )
#
# File c:\Users\admin1\Desktop\New folder\myvenv\Lib\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'stop_words' parameter of CountVectorizer must be a str among {'english'}, an instance of 'list' or None. Got frozenset({'against', 'hundred', 'everywhere', 'anyway', 'least', 'will', 'however', 'even', 'whenever', 'which', 'something', 'herself', 'etc', 'because', 'thereupon', 'mill', 'perhaps', 'thereby', 'moreover', 'becomes', 'again', 'themselves', 'whatever', 'it', 'whoever', 'de', 'my', 'put', 'fifty', 'should', 'either', 'somewhere', 'where', 'everyone', 'she', 'ltd', 'must', 'show', 'full', 'between', 'whose', 'of', 'yourself', 'empty', 'under', 'never', 'among', 'therefore', 'formerly', 'some', 'interest', 'about', 'what', 'to', 'being', 'once', 'thereafter', 'un', 'since', 'system', 'as', 'nobody', 'throughout', 'sometimes', 'whole', 'or', 'thence', 'cant', 'twenty', 'bottom', 'several', 'wherever', 'namely', 'same', 'six', 'by', 'with', 'less', 'still', 'over', 'you', 'sixty', 'within', 'fire', 'except', 'her', 'call', 'has', 'only', 'own', 'five', 'anything', 'if', 'towards', 'twelve', 'always', 'two', 'amoungst', 'me', 'might', 'myself', 'until', 'eight', 'became', 'con', 'first', 'couldnt', 'describe', 'someone', 'mostly', 'now', 'its', 'part', 'is', 'seemed', 'very', 'move', 'could', 'nowhere', 'keep', 'then', 'were', 'around', 'together', 'an', 'latterly', 'itself', 'all', 'few', 'inc', 'them', 'when', 'third', 'becoming', 'behind', 'no', 'below', 'via', 'during', 'whereafter', 'thin', 'made', 'name', 'wherein', 'already', 'amongst', 'latter', 'eleven', 'nor', 'here', 'somehow', 'per', 'after', 'who', 'side', 'hers', 'eg', 'else', 'go', 'anyhow', 'well', 'fill', 'can', 'amount', 'upon', 'but', 'although', 'been', 'have', 'seems', 'anywhere', 'front', 'am', 'sometime', 'these', 'alone', 'so', 'four', 'both', 'other', 'along', 'before', 'give', 'toward', 'therein', 'whether', 'in', 'i', 'nevertheless', 'into', 'him', 'their', 'your', 'three', 'whereas', 'thus', 'meanwhile', 'none', 'back', 'hereupon', 'he', 'former', 'than', 'ourselves', 'afterwards', 'his', 'please', 'thick', 'enough', 'last', 'beside', 'us', 'due', 'from', 'whereby', 'whereupon', 'cry', 'see', 'many', 'that', 'found', 'much', 'further', 'was', 'become', 'off', 'at', 'on', 'ie', 'though', 'out', 'we', 'are', 'elsewhere', 'often', 'fifteen', 'one', 'detail', 'they', 'any', 'thru', 'most', 'do', 'and', 're', 'hasnt', 'too', 'besides', 'noone', 'whither', 'cannot', 'without', 'not', 'another', 'hereby', 'beforehand', 'down', 'hereafter', 'anyone', 'such', 'sincere', 'those', 'had', 'our', 'up', 'hence', 'everything', 'ten', 'through', 'bill', 'ours', 'every', 'for', 'get', 'co', 'may', 'why', 'almost', 'how', 'each', 'nothing', 'serious', 'seeming', 'yet', 'next', 'the', 'top', 'otherwise', 'mine', 'ever', 'himself', 'this', 'whom', 'be', 'also', 'above', 'find', 'whence', 'while', 'would', 'across', 'rather', 'forty', 'done', 'neither', 'onto', 'indeed', 'there', 'herein', 'nine', 'beyond', 'yourselves', 'others', 'a', 'seem', 'take', 'more', 'yours'}) instead.

# %%
# Show th DTM. 
X

# %%
# Size of X (=m x n). m = number of documents = 7 & n = number of features.
X.shape

# %%
# View the features.
features = vectorizer.get_feature_names()
print(features)

# %% [markdown]
# #### 1.2. Apply the LDA:

# %%
# Get the topics.
n_topics = 4
lda = LatentDirichletAllocation(n_components=n_topics, random_state=123)
my_docs_topic = lda.fit_transform(X)

# %%
# row = document, column = topic.
my_docs_topic

# %%
# Sum along the row has to give 1.
my_docs_topic.sum(axis=1)

# %% [markdown]
# #### 1.3. From each topic, extract the top features:

# %%
topic_composition = lda.components_
topic_composition.shape     # row = topic, column = feature (word).

# %%
n_top = 3
for i in range(n_topics):
    topic_features = [features[idx] for idx in np.argsort(-topic_composition[i,:])]   # argsort() shows the sorted index.
    topic_features_top = topic_features[0:n_top]
    if i == 0:
        topic_matrix = [topic_features_top]                    # list의 list 만들 준비!
    else:
        topic_matrix.append(topic_features_top)

# %%
# Show the top features for each topic.
topic_matrix

# %%
# In view of the top features, we can name the topics.
topic_names = ['Technology', 'Cuisine', 'Movie','Economy']

# %% [markdown]
# #### 1.4. Label each document with the most predominant topic:

# %%
# The most probable topic is given directly by the LDA output.
n_docs = len(my_docs)
for i in range(n_docs):
    topic_pick = np.argmax(my_docs_topic[i,:])
    print("Document " + str(i+1) + " = " + topic_names[topic_pick])

# %% [markdown]
# **NOTE**: We can notice some inaccuracies.
