# %%
import pandas as pd
import numpy as np

# %%
student_data = pd.DataFrame([['Name', 'Age','Gender','Course','City'],['Shashank',21,'M','B.Tech','Bangalore'],['Ravi',22,'M','B.Tech','Chennai'],['Anjali',20,'F','B.Sc','Mumbai'],['Sneha',21,'F','B.Com','Delhi']])

# %%
student_data
# Out:
#           0    1       2       3          4
# 0      Name  Age  Gender  Course       City
# 1  Shashank   21       M  B.Tech  Bangalore
# 2      Ravi   22       M  B.Tech    Chennai
# 3    Anjali   20       F    B.Sc     Mumbai
# 4     Sneha   21       F   B.Com      Delhi

# %%
student_data = pd.DataFrame([['Shashank',21,'M','B.Tech','Bangalore'],['Ravi',22,'M','B.Tech','Chennai'],['Anjali',20,'F','B.Sc','Mumbai'],['Sneha',21,'F','B.Com','Delhi']], columns=['Name','Age','Gender','Course','City'])
#Updating Column Names from default to custom values

# %%
student_data
# Out:
#        Name  Age Gender  Course       City
# 0  Shashank   21      M  B.Tech  Bangalore
# 1      Ravi   22      M  B.Tech    Chennai
# 2    Anjali   20      F    B.Sc     Mumbai
# 3     Sneha   21      F   B.Com      Delhi

# %%
student_data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#Updating Index with custom values
student_data.index = ['Stud1','Stud2','Stud3','Stud4']

# %%
student_data
# Out:
#            Name  Age Gender  Course       City
# Stud1  Shashank   21      M  B.Tech  Bangalore
# Stud2      Ravi   22      M  B.Tech    Chennai
# Stud3    Anjali   20      F    B.Sc     Mumbai
# Stud4     Sneha   21      F   B.Com      Delhi

# %%
student_data.index
# Out:
# Index(['Stud1', 'Stud2', 'Stud3', 'Stud4'], dtype='object')

# %%
#Renaming columns
student_data.columns = ['Student_Name','Student_Age','Student_Gender','Student_Course','Student_City']

# %%
student_data
# Out:
#       Student_Name  Student_Age Student_Gender Student_Course Student_City
# Stud1     Shashank           21              M         B.Tech    Bangalore
# Stud2         Ravi           22              M         B.Tech      Chennai
# Stud3       Anjali           20              F           B.Sc       Mumbai
# Stud4        Sneha           21              F          B.Com        Delhi

# %%
student_data.rename(columns={'Student_Name':'Name','Student_Age':'Age'}, inplace=True)

# %%
student_data
# Out:
#            Name  Age Student_Gender Student_Course Student_City
# Stud1  Shashank   21              M         B.Tech    Bangalore
# Stud2      Ravi   22              M         B.Tech      Chennai
# Stud3    Anjali   20              F           B.Sc       Mumbai
# Stud4     Sneha   21              F          B.Com        Delhi

# %%
#Drop a column just once
student_data.drop('Stud1')
# Out:
#          Name  Age Student_Gender Student_Course Student_City
# Stud2    Ravi   22              M         B.Tech      Chennai
# Stud3  Anjali   20              F           B.Sc       Mumbai
# Stud4   Sneha   21              F          B.Com        Delhi

# %%
student_data
# Out:
#            Name  Age Student_Gender Student_Course Student_City
# Stud1  Shashank   21              M         B.Tech    Bangalore
# Stud2      Ravi   22              M         B.Tech      Chennai
# Stud3    Anjali   20              F           B.Sc       Mumbai
# Stud4     Sneha   21              F          B.Com        Delhi

# %%
#Drop a column permanently
student_data.drop('Stud3', inplace=True)

# %%
student_data
# Out:
#            Name  Age Student_Gender Student_Course Student_City
# Stud1  Shashank   21              M         B.Tech    Bangalore
# Stud2      Ravi   22              M         B.Tech      Chennai
# Stud4     Sneha   21              F          B.Com        Delhi

# %%
student_data1 = student_data[:]

# %%
student_data1
# Out:
#            Name  Age Student_Gender Student_Course Student_City
# Stud1  Shashank   21              M         B.Tech    Bangalore
# Stud2      Ravi   22              M         B.Tech      Chennai
# Stud4     Sneha   21              F          B.Com        Delhi

# %%
student_data2 = student_data[1:]

# %%
student_data2
# Out:
#         Name  Age Student_Gender Student_Course Student_City
# Stud2   Ravi   22              M         B.Tech      Chennai
# Stud4  Sneha   21              F          B.Com        Delhi

# %%
student_data3 = student_data[:1]

# %%
student_data3
# Out:
#            Name  Age Student_Gender Student_Course Student_City
# Stud1  Shashank   21              M         B.Tech    Bangalore
