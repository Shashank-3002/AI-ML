# %%
import numpy as np
import pandas as pd

# %%
eam_data = {'name': ['honggildong', 'kimyuna', 'parkjiwoo', 'leeseulgi'],
            'math': [90, 80, 70, 60],
            'english': [85, 95, 75, 65],
            'music': [100, 90, 80, 70],
            'physics': [95, 85, 75, 65]}

# %%
df = pd.DataFrame(eam_data)
df
# Out:
#           name  math  english  music  physics
# 0  honggildong    90       85    100       95
# 1      kimyuna    80       95     90       85
# 2    parkjiwoo    70       75     80       75
# 3    leeseulgi    60       65     70       65

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# Changing index labels to custom values using list
df.index = ['one', 'two', 'three', 'four']

# %%
df.index
# Out:
# Index(['one', 'two', 'three', 'four'], dtype='object')

# %%
df
# Out:
#               name  math  english  music  physics
# one    honggildong    90       85    100       95
# two        kimyuna    80       95     90       85
# three    parkjiwoo    70       75     80       75
# four     leeseulgi    60       65     70       65

# %%
# Accessing rows using custom index labels
df.loc['three'] # Accessing row with index label 'three' which displays all columns for that row in a Series format
# Out:
# name       parkjiwoo
# math              70
# english           75
# music             80
# physics           75
# Name: three, dtype: object

# %%
df.loc[['three']] # Accessing row with index label 'three' which displays all columns for that row in a DataFrame format
# Out:
#             name  math  english  music  physics
# three  parkjiwoo    70       75     80       75

# %%
df['english'] # Accessing column using column name
# Out:
# one      85
# two      95
# three    75
# four     65
# Name: english, dtype: int64

# %%
df['music'] # Accessing another column using column name which displays all rows for that column in a Series format
# Out:
# one      100
# two       90
# three     80
# four      70
# Name: music, dtype: int64

# %%
df[['music', 'english']]  # Accessing multiple columns using list with column names which displays all rows for those columns in a DataFrame format
# Out:
#        music  english
# one      100       85
# two       90       95
# three     80       75
# four      70       65

# %%
#Setting the names as the index
df.set_index('name', inplace=True)

# %%
df  # Accessing rows using new integer index labels
# Out:
#              math  english  music  physics
# name
# honggildong    90       85    100       95
# kimyuna        80       95     90       85
# parkjiwoo      70       75     80       75
# leeseulgi      60       65     70       65

# %%
df
# Out:
#              math  english  music  physics
# name
# honggildong    90       85    100       95
# kimyuna        80       95     90       85
# parkjiwoo      70       75     80       75
# leeseulgi      60       65     70       65

# %%
a = df.loc['parkjiwoo', 'music'] # Accessing specific value using loc with row and column labels

# %%
print(a)
# Out:
# 80

# %%
b = df.iloc[1, 3] # Accessing specific value using iloc with row and column positions

# %%
print(b)
# Out:
# 85

# %%
c = df.loc['kimyuna', ['music', 'english']]  # Accessing row using loc with row label

# %%
print(c)
# Out:
# music      90
# english    95
# Name: kimyuna, dtype: int64

# %%
df.loc['leeseulgi', ['math', 'english']] = 90,95 # Updating specific values using loc with row label and column labels

# %%
df
# Out:
#              math  english  music  physics
# name
# honggildong    90       85    100       95
# kimyuna        80       95     90       85
# parkjiwoo      70       75     80       75
# leeseulgi      90       95     70       65

# %%
df.mean()
# Out:
# math       82.5
# english    87.5
# music      85.0
# physics    80.0
# dtype: float64

# %%
# df.avg()  # This will raise an AttributeError since 'DataFrame' object has no attribute 'avg'
df.median()  # This will work correctly and return the median of each column
# Out:
# math       85.0
# english    90.0
# music      85.0
# physics    80.0
# dtype: float64

# %%
d =df.iloc[0, [1, 2]] # Accessing specific values using iloc with row position and list of column positions

# %%
print(d)
# Out:
# english     85
# music      100
# Name: honggildong, dtype: int64

# %%
d =df.iloc[3, [0, 3]] # Accessing specific values using iloc with row position and list of column positions

# %%
print(d)
# Out:
# math       90
# physics    65
# Name: leeseulgi, dtype: int64

# %%
df.iloc[1:3, 1:3] # Accessing a subset of the DataFrame using iloc with row and column position ranges
# Out:
#            english  music
# name
# kimyuna         95     90
# parkjiwoo       75     80

# %%
df.iloc[1, 1:3] # Accessing a subset of the DataFrame using iloc with row position and column position ranges
# Out:
# english    95
# music      90
# Name: kimyuna, dtype: int64

# %%
df.loc['kimyuna' : 'leeseulgi', 'math' :  'music']  # Accessing multiple rows and columns using loc with row and column labels
# Out:
#            math  english  music
# name
# kimyuna      80       95     90
# parkjiwoo    70       75     80
# leeseulgi    90       95     70

# %%
df['Chemistry'] = [100, 90, 80, 70]  # Adding a new column to the DataFrame

# %%
df
# Out:
#              math  english  music  physics  Chemistry
# name
# honggildong    90       85    100       95        100
# kimyuna        80       95     90       85         90
# parkjiwoo      70       75     80       75         80
# leeseulgi      90       95     70       65         70

# %%
df.reindex
# Out:
# <bound method DataFrame.reindex of              math  english  music  physics  Chemistry
# name
# honggildong    90       85    100       95        100
# kimyuna        80       95     90       85         90
# parkjiwoo      70       75     80       75         80
# leeseulgi      90       95     70       65         70>

# %%
df
# Out:
#              math  english  music  physics  Chemistry
# name
# honggildong    90       85    100       95        100
# kimyuna        80       95     90       85         90
# parkjiwoo      70       75     80       75         80
# leeseulgi      90       95     70       65         70

# %%
df.reset_index()
# Out:
#           name  math  english  music  physics  Chemistry
# 0  honggildong    90       85    100       95        100
# 1      kimyuna    80       95     90       85         90
# 2    parkjiwoo    70       75     80       75         80
# 3    leeseulgi    90       95     70       65         70

# %%
df.iloc[1:3, 1:3] # Accessing a subset of the DataFrame using iloc with row and column position ranges
# Out:
#            english  music
# name
# kimyuna         95     90
# parkjiwoo       75     80

# %%
df.iloc[3]
# Out:
# math         90
# english      95
# music        70
# physics      65
# Chemistry    70
# Name: leeseulgi, dtype: int64

# %%
# df.loc[4] = ['johndoe', 88, 77, 66, 55, 99]  # Adding a new row to the DataFrame using loc with a new index label
df.loc[4] = 0

# %%
df
# Out:
#              math  english  music  physics  Chemistry
# name
# honggildong    90       85    100       95        100
# kimyuna        80       95     90       85         90
# parkjiwoo      70       75     80       75         80
# leeseulgi      90       95     70       65         70
# 4               0        0      0        0          0

# %%
df.loc[4] = [88, 77, 66, 55, 99]  # Adding a new row using loc with a new index label

# %%
df
# Out:
#              math  english  music  physics  Chemistry
# name
# honggildong    90       85    100       95        100
# kimyuna        80       95     90       85         90
# parkjiwoo      70       75     80       75         80
# leeseulgi      90       95     70       65         70
# 4              88       77     66       55         99

# %%
df.iloc[]
