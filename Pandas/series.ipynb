# %%
#Update pandas using pip
# %pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
print(pd.__version__)  #Pandas version
# Out:
# 2.3.2

# %%
import numpy as np

# %%
#Simple series creation using pandas
pd.Series(['Shashank','Lohit','Sai','Prateek'])
# Out:
# 0    Shashank
# 1       Lohit
# 2         Sai
# 3     Prateek
# dtype: object

# %%
#Series creation using numpy and pandas
names = pd.Series(np.array(['Shashank','Lohit','Sai','Prateek']))

# %%
names
# Out:
# 0    Shashank
# 1       Lohit
# 2         Sai
# 3     Prateek
# dtype: object

# %%
names[0]  #Accessing first element of series
# Out:
# 'Shashank'

# %%
names.dtype  #Data type of series
# Out:
# dtype('O')

# %%
type(names)  #Type of series
# Out:
# pandas.core.series.Series

# %%
print(names.index) #Index of series
# Out:
# RangeIndex(start=0, stop=4, step=1)
# ['Shashank' 'Lohit' 'Sai' 'Prateek']

# %%
print(names.values) #Values of series
# Out:
# ['Shashank' 'Lohit' 'Sai' 'Prateek']

# %%
import pandas as pd

# %%
BG = pd.Series(['A+','B+','O+','AB+','A-'])

# %%
BG
# Out:
# 0     A+
# 1     B+
# 2     O+
# 3    AB+
# 4     A-
# dtype: object

# %%
import numpy as np

# %%
Age =pd.Series(np.array([21,35,48,65,89]))

# %%
Age
# Out:
# 0    21
# 1    35
# 2    48
# 3    65
# 4    89
# dtype: int64

# %%
demo = pd.Series(np.array([1, True, 'A+', 'Bob', 23]))

# %%
demo
# Out:
# 0       1
# 1    True
# 2      A+
# 3     Bob
# 4      23
# dtype: object

# %%
Dict = pd.Series({'Name':["bob","Harry","Tom","Allice","Eve"]})

# %%
Dict
# Out:
# Name    [bob, Harry, Tom, Allice, Eve]
# dtype: object

# %%
Dict_2= pd.Series({'Name':"bob",'Age':25,'BG':"A+",'Is_married':"False", 'Height':5.9})

# %%
Dict_2
# Out:
# Name            bob
# Age              25
# BG               A+
# Is_married    False
# Height          5.9
# dtype: object

# %%
Dict_2.index
# Out:
# Index(['Name', 'Age', 'BG', 'Is_married', 'Height'], dtype='object')

# %%
Dict_2.index.values
# Out:
# array(['Name', 'Age', 'BG', 'Is_married', 'Height'], dtype=object)

# %%
Dict_2.values
# Out:
# array(['bob', 25, 'A+', 'False', 5.9], dtype=object)

# %%
pd.DataFrame({'Name':["Braud","Harry","Tom"],
              'Age':[25,35,86],
              'Sex':["Male","Female","Male"]})
# Out:
#     Name  Age     Sex
# 0  Braud   25    Male
# 1  Harry   35  Female
# 2    Tom   86    Male

# %%
df=pd.DataFrame({'Name':["Braud","Harry","Tom"],
              'Age':[25,35,86],
              'Sex':["Male","Female","Male"]})

# %%
df['Age']
# Out:
# 0    25
# 1    35
# 2    86
# Name: Age, dtype: int64

# %%
df['Name']
# Out:
# 0    Braud
# 1    Harry
# 2      Tom
# Name: Name, dtype: object

# %%
df['Sex']
# Out:
# 0      Male
# 1    Female
# 2      Male
# Name: Sex, dtype: object

# %%
df['Age'][2]
# Out:
# np.int64(86)

# %%
df['Name'][2]
# Out:
# 'Tom'

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Sex'], dtype='object')

# %%
import pandas as pd

# %%
Iris = pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 Iris = pd.read_csv()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'
