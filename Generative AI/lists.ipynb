# %%
#Lists
lst = [10,20,30,40,50]
print(lst)
print(type(lst))
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>

# %%
names_list = ["Alice", "Bob", "Charlie", "David", 10,20,50,60]
print(names_list)
print(type(names_list))#Prints the type of the list
print(type(names_list[3])) #Prints
# Out:
# ['Alice', 'Bob', 'Charlie', 'David']
# <class 'list'>
# <class 'str'>
