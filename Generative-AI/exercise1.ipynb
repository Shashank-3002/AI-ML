# %%
#To lowercase 
"Hello! How are you?".lower()
# Out:
# 'hello! how are you?'

# %%
x = "Hello Welcome,to Krish Naik's NLP Tutorials."
y = "Please do watch the entire course! to become expert in NLP."
" ".join(x)
# Out:
# "H e l l o   W e l c o m e , t o   K r i s h   N a i k ' s   N L P   T u t o r i a l s ."

# %%
print(len(x))
print(len(y))
# Out:
# 44
# 59

# %%
print(y.count('e'))
print(x.count('t'))
# Out:
# 10
# 2

# %%
#Extracting sub-string
y[0:12]
# Out:
# 'Please do wa'

# %%
import requests as re
x1 ="That is your book."
x2 ="This is my book."

# %%
my_exp = "^This"

# %%
if re.sear(my_exp, x1):
    print("yes")
else:
    print("No")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 if re.search(my_exp, x1):
#       2     print(yes)
#       3 else:
#
# AttributeError: module 'requests' has no attribute 'search'
