# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (4.57.1)
# Requirement already satisfied: filelock in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shash\onedrive\desktop\samsunginnovationcampus-ai-ml\samsunginnovationcampus-ai-ml\venv\lib\site-packages (from requests->transformers) (2025.10.5)

# %% [markdown]
# ##### BERT (Bidirectional Encoder Representations from Transformers) leverages a transformer-based neural network to understand and generate human-like language. BERT employs an encoder-only architecture.

# %%
from transformers import BertTokenizer

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
text = 'ChatGPT is a language model developed by OpenAI, based on the GPT (Generative Pre-trained Transformer) architecture. '

# Tokenize and encode the text
encoding = tokenizer.encode(text)
print("Token IDs:", encoding)

# Convert token IDs back to tokens
tokens = tokenizer.convert_ids_to_tokens(encoding)
print("Tokens:", tokens)
# Out:
# Token IDs: [101, 24705, 1204, 17095, 1942, 1110, 170, 1846, 2235, 1872, 1118, 3353, 1592, 2240, 117, 1359, 1113, 1103, 15175, 1942, 113, 9066, 15306, 11689, 118, 3972, 13809, 23763, 114, 4220, 119, 102]
# Tokens: ['[CLS]', 'Cha', '##t', '##GP', '##T', 'is', 'a', 'language', 'model', 'developed', 'by', 'Open', '##A', '##I', ',', 'based', 'on', 'the', 'GP', '##T', '(', 'Gene', '##rative', 'Pre', '-', 'trained', 'Trans', '##former', ')', 'architecture', '.', '[SEP]']
